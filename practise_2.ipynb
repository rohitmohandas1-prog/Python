# %%
y = lambda x,y: print (x + y)
y(2,3)
print()
# Out:
# 5

# %%
y = lambda x,y: print (x/ y)
y(10,3)
print()
# Out:
# 3.3333333333333335

# %%
discount = lambda ticket_price: ticket_price - (ticket_price * 0.20)

ticket_price = int(input("Enter the ticket price: "))
print("Discounted price:", discount(ticket_price))
# Out:
# Discounted price: 120000.0

# %%
passengers = [
   "Rahul Sharma",
   "Priya Singh",
   "Amit Verma"]

seats = [
   "B1-21",
   "B1-22",
   "B1-23"]

reservation_data = list(
    zip(passengers, seats))

print(reservation_data)
# Out:
# [('Rahul Sharma', 'B1-21'), ('Priya Singh', 'B1-22'), ('Amit Verma', 'B1-23')]

# %%
ticket_fares = [2500, 800, 3200, 600]
valid_fares = list(
   filter(
       lambda fare: fare > 1000,
       ticket_fares))
final_fares = list(
   map(
       lambda fare: fare + 100,
       valid_fares))

# %%
li = [10,45,23,55,67,33,22,14]

# %%
class Train:

   train_name = "Rajdhani Express"
   source_station = "Mumbai"
   destination_station = "Delhi"

train1 = Train()

print("Train Name :", train1.train_name)
print("Source Station :", train1.source_station)
print("Destination Station :", train1.destination_station)
# Out:
# Train Name : Rajdhani Express
# Source Station : Mumbai
# Destination Station : Delhi

# %%
class Reservation:

   train_name = "Rajdhani Express"
   def reservation_status(self):
         print("Reservation is confirmed")

ticket1 = Reservation()
ticket2 = Reservation()

print(ticket1.train_name)
print(ticket2.train_name)
ticket1.reservation_status()
ticket2.reservation_status()
# Out:
# Rajdhani Express
# Rajdhani Express
# Reservation is confirmed
# Reservation is confirmed

# %%
class RailwayReservation:

   train_name = "Rajdhani Express"
   passenger_name = "Priya Singh"
   seat_number = "A1-21"
   ticket_price = 2450

   def display_ticket(self):

       print("===================================")
       print(" Railway Reservation Ticket ")
       print("===================================")
       print("Passenger Name :", self.passenger_name)
       print("Train Name :", self.train_name)
       print("Seat Number :", self.seat_number)
       print("Ticket Price :", self.ticket_price)
       print("Reservation Status : Confirmed")


ticket = RailwayReservation()
ticket.display_ticket()
# Out:
# ===================================
#  Railway Reservation Ticket
# ===================================
# Passenger Name : Priya Singh
# Train Name : Rajdhani Express
# Seat Number : A1-21
# Ticket Price : 2450
# Reservation Status : Confirmed

# %%
class RailwayReservation:

    def __init__(
        self,
        passenger_name,
        train_name,
        seat_number
    ):

        self.passenger_name = passenger_name
        self.train_name = train_name
        self.seat_number = seat_number

        self.passenger_name = passenger_name
        self.train_name = train_name
        self.seat_number = seat_number

        ticket1= RailwayReservation(
            "Rahul Sharma",
            "Rajdhani Express", 
            "A1-21")

        print(ticket1.passenger_name)
        print(ticket1.train_name)
        print(ticket1.seat_number)

# %%
class RailwayReservation:

    def __init__(
        self,
        passenger_name,
        train_name,
        seat_number,
        ticket_price):

        self.passenger_name = passenger_name
        self.train_name = train_name
        self.seat_number = seat_number
        self.ticket_price = ticket_price
        print("Reservation Created Successfully")

    def display_ticket(self):

        print("===================================")
        print(" Railway Reservation Ticket ")
        print("===================================")
        print("Passenger Name :", self.passenger_name)
        print("Train Name :", self.train_name)
        print("Seat Number :", self.seat_number)
        print("Ticket Price :", self.ticket_price)

    def __del__(self):
        print("Reservation Cancelled")

    ticket1 = RailwayReservation(
    "Neha Kapoor",
    "Rajdhani Express",
    "A1-25",
    2450)
    ticket1.display_ticket()

    del ticket1
# Out:
# Reservation Created Successfully
# ===================================
#  Railway Reservation Ticket
# ===================================
# Passenger Name : Neha Kapoor
# Train Name : Rajdhani Express
# Seat Number : A1-25
# Ticket Price : 2450
# Reservation Cancelled

# %%
class Car:
    def __init__(self):
        self.brand = "BMW"        # public
        self._model = "X1"        # protected (convention)
        self.__price = 5000000    # private

c = Car()

print(c.brand)      # allowed
print(c._model)     # allowed but not recommended
print(c.__price)    # not accessible directly
# Out:
# BMW
# X1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 11
#       7 c = Car()
#       8
#       9 print(c.brand)      # allowed
#      10 print(c._model)     # allowed but not recommended
# ---> 11 print(c.__price)    # not accessible directly
#
# AttributeError: 'Car' object has no attribute '__price'
