# %%
from bs4 import BeautifulSoup
import requests

url = "https://contentitvedant.github.io/Railway_Booking/index.html"

response = requests.get(url)

	
print("Status Code :", response.status_code)

print("Page Fetched Successfully")
# Out:
# Status Code : 200
# Page Fetched Successfully

# %%
import requests           #Extract all Train Numbers
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/index.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")

train_numbers = soup.find_all(class_="train-number")

print("Train Numbers on IndRail:")
print("=" * 30)
for item in train_numbers:
    print(item.get_text())
# Out:
# Train Numbers on IndRail:
# ==============================
# 12951
# 12163
# 12301
# 12657

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/trains.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")

table = soup.find(id="train-schedule-table")
rows  = table.find("tbody").find_all("tr")

print("Train Schedule:")
print("=" * 60)

for row in rows:
    cells      = row.find_all("td")
    train_no   = cells[0].get_text()
    train_name = cells[1].get_text()
    from_stn   = cells[2].get_text()
    to_stn     = cells[3].get_text()
    departure  = cells[4].get_text()
    arrival    = cells[5].get_text()
    duration   = cells[6].get_text()

    print(train_no, "|", train_name)
    print("   From :", from_stn, "-> To :", to_stn)
    print("   Departure :", departure, "| Arrival :", arrival, "| Duration :", duration)
    print("-" * 60)
# Out:
# Train Schedule:
# ============================================================
# 12951 | Mumbai Rajdhani Express
#    From : Mumbai Central (BCT) -> To : Delhi Junction (DLI)
#    Departure : 17:00 | Arrival : 08:35 (+1) | Duration : 15h 35m
# ------------------------------------------------------------
# 12952 | New Delhi Rajdhani Express
#    From : Delhi Junction (DLI) -> To : Mumbai Central (BCT)
#    Departure : 16:55 | Arrival : 08:15 (+1) | Duration : 15h 20m
# ------------------------------------------------------------
# 12163 | Chennai Superfast Express
#    From : Mumbai CST (CSTM) -> To : Chennai Central (MAS)
#    Departure : 23:45 | Arrival : 03:30 (+2) | Duration : 27h 45m
# ------------------------------------------------------------
# 12301 | Howrah Rajdhani Express
#    From : Howrah (HWH) -> To : Delhi Junction (DLI)
#    Departure : 14:05 | Arrival : 09:55 (+1) | Duration : 19h 50m
# ------------------------------------------------------------
# 12657 | Bangalore Mail
#    From : Chennai Central (MAS) -> To : Bangalore City (SBC)
#    Departure : 22:00 | Arrival : 05:30 (+1) | Duration : 7h 30m
# ------------------------------------------------------------
# 11301 | Udyan Express
#    From : Mumbai CST (CSTM) -> To : Bangalore City (SBC)
#    Departure : 08:05 | Arrival : 11:35 (+1) | Duration : 27h 30m
# ------------------------------------------------------------
# 12246 | Yuva Express
#    From : Howrah (HWH) -> To : Pune Junction (PUNE)
#    Departure : 11:35 | Arrival : 21:00 (+1) | Duration : 33h 25m
# ------------------------------------------------------------
# 19019 | Dehradun Express
#    From : Ahmedabad Junction (ADI) -> To : Delhi Junction (DLI)
#    Departure : 06:20 | Arrival : 05:10 (+1) | Duration : 22h 50m
# ------------------------------------------------------------
# 22691 | Rajdhani Express
#    From : Bangalore City (SBC) -> To : Delhi Junction (DLI)
#    Departure : 20:00 | Arrival : 05:30 (+2) | Duration : 33h 30m
# ------------------------------------------------------------
# 12621 | Tamil Nadu Express
#    From : Delhi Junction (DLI) -> To : Chennai Central (MAS)
#    Departure : 22:30 | Arrival : 07:10 (+2) | Duration : 32h 40m
# ------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/passengers.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")

table = soup.find(id="passenger-records-table")
rows  = table.find("tbody").find_all("tr")

print("Passenger Records:")
print("=" * 60)

for row in rows:
    pnr  = row["data-pnr"]
    name = row.find(class_="passenger-name").get_text()
    date = row.find(class_="journey-date").get_text()
    cls  = row.find(class_="travel-class").get_text()
    seat = row.find(class_="seat-number").get_text()
    fare = row.find(class_="fare").get_text()

    print("PNR  :", pnr)
    print("Name :", name)
    print("Date :", date, "| Class :", cls, "| Seat :", seat, "| Fare : Rs.", fare)
    print("-" * 60)
# Out:
# Passenger Records:
# ============================================================
# PNR  : 43821756
# Name : Rahul Sharma
# Date : 2024-11-15 | Class : 3A | Seat : B4 | Fare : Rs. 880
# ------------------------------------------------------------
# PNR  : 67934521
# Name : Priya Menon
# Date : 2024-11-16 | Class : 2A | Seat : A12 | Fare : Rs. 1220
# ------------------------------------------------------------
# PNR  : 81204763
# Name : Arjun Nair
# Date : 2024-11-17 | Class : SL | Seat : — | Fare : Rs. 420
# ------------------------------------------------------------
# PNR  : 52983104
# Name : Sunita Rao
# Date : 2024-11-18 | Class : 2A | Seat : C7 | Fare : Rs. 1220
# ------------------------------------------------------------
# PNR  : 39047682
# Name : Vikram Patel
# Date : 2024-11-20 | Class : 3A | Seat : D23 | Fare : Rs. 880
# ------------------------------------------------------------
# PNR  : 74512839
# Name : Kavya Iyer
# Date : 2024-11-19 | Class : SL | Seat : — | Fare : Rs. 420
# ------------------------------------------------------------
# PNR  : 60183475
# Name : Aditya Joshi
# Date : 2024-11-22 | Class : 1A | Seat : A3 | Fare : Rs. 2170
# ------------------------------------------------------------
# PNR  : 95261847
# Name : Deepa Krishnan
# Date : 2024-11-21 | Class : 3A | Seat : B18 | Fare : Rs. 880
# ------------------------------------------------------------
# PNR  : 12873649
# Name : Mohan Das
# Date : 2024-11-15 | Class : 2A | Seat : A6 | Fare : Rs. 1220
# ------------------------------------------------------------
# PNR  : 48730261
# Name : Ananya Singh
# Date : 2024-11-23 | Class : SL | Seat : C31 | Fare : Rs. 420
# ------------------------------------------------------------
# PNR  : 33918274
# Name : Ravi Kumar
# Date : 2024-11-24 | Class : 3A | Seat : D9 | Fare : Rs. 880
# ------------------------------------------------------------
# PNR  : 76459013
# Name : Neha Gupta
# Date : 2024-11-25 | Class : 3A | Seat : B55 | Fare : Rs. 880
# ------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
url = "https://contentitvedant.github.io/Railway_Booking/seat-availability.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")

table = soup.find(id="seat-availability-table")
rows  = table.find("tbody").find_all("tr")

print("Seat Availability Report:")
print("=" * 60)

for row in rows:
    train_no   = row["data-train"]
    train_name = row.find(class_="train-name").get_text()
    seats_sl   = row.find(class_="seats-sl").get_text()
    seats_3a   = row.find(class_="seats-3a").get_text()
    seats_2a   = row.find(class_="seats-2a").get_text()
    seats_1a   = row.find(class_="seats-1a").get_text()

    print("Train", train_no, "-", train_name)
    print("  SL :", seats_sl, "| 3A :", seats_3a, "| 2A :", seats_2a, "| 1A :", seats_1a)
    print("-" * 60)
# Out:
# Seat Availability Report:
# ============================================================
# Train 12951 - Mumbai Rajdhani Express
#   SL : — | 3A : 42 | 2A : 18 | 1A : 6
# ------------------------------------------------------------
# Train 12952 - New Delhi Rajdhani Express
#   SL : — | 3A : 27 | 2A : 11 | 1A : 4
# ------------------------------------------------------------
# Train 12163 - Chennai Superfast Express
#   SL : 14 | 3A : 5 | 2A : 2 | 1A : —
# ------------------------------------------------------------
# Train 12301 - Howrah Rajdhani Express
#   SL : — | 3A : 38 | 2A : 15 | 1A : 5
# ------------------------------------------------------------
# Train 12657 - Bangalore Mail
#   SL : 0 | 3A : 0 | 2A : 0 | 1A : —
# ------------------------------------------------------------
# Train 11301 - Udyan Express
#   SL : 63 | 3A : 22 | 2A : 8 | 1A : —
# ------------------------------------------------------------
# Train 12246 - Yuva Express
#   SL : 3 | 3A : 1 | 2A : 0 | 1A : —
# ------------------------------------------------------------
# Train 19019 - Dehradun Express
#   SL : 81 | 3A : 34 | 2A : 12 | 1A : 3
# ------------------------------------------------------------
# Train 22691 - Rajdhani Express
#   SL : — | 3A : 9 | 2A : 3 | 1A : 1
# ------------------------------------------------------------
# Train 12621 - Tamil Nadu Express
#   SL : 0 | 3A : 0 | 2A : 0 | 1A : —
# ------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup

class RailwayScraper:

    def __init__(self):
        self.base_url = "https://contentitvedant.github.io/Railway_Booking/"

    def get_soup(self, page):
        url      = self.base_url + page
        response = requests.get(url)
        soup     = BeautifulSoup(response.text, "html.parser")
        print("Fetched :", url, "| Status :", response.status_code)
        return soup

    def get_train_schedule(self):
        soup   = self.get_soup("trains.html")
        table  = soup.find(id="train-schedule-table")
        rows   = table.find("tbody").find_all("tr")
        trains = []
        
        for row in rows:
            cells = row.find_all("td")
            trains.append({
                
                "train_no"   : cells[0].get_text(),
                "train_name" : cells[1].get_text(),
                "from"       : cells[2].get_text(),
                "to"         : cells[3].get_text(),
                "departure"  : cells[4].get_text(),
                "arrival"    : cells[5].get_text(),
                "duration"   : cells[6].get_text(),
            })
        return trains
    def get_seat_availability(self):
        soup      = self.get_soup("seat-availability.html")
        table     = soup.find(id="seat-availability-table")
        rows      = table.find("tbody").find_all("tr")
        available = []
        for row in rows:
            available.append({
                "train_no"   : row["data-train"],
                "train_name" : row.find(class_="train-name").get_text(),
                "seats_sl"   : row.find(class_="seats-sl").get_text(),
                "seats_3a"   : row.find(class_="seats-3a").get_text(),
                "seats_2a"   : row.find(class_="seats-2a").get_text(),
                "seats_1a"   : row.find(class_="seats-1a").get_text(),
            })
        return available
                
scraper = RailwayScraper()
print("\n--- TRAIN SCHEDULE ---")
for train in scraper.get_train_schedule():
    print(
        train["train_no"], "|",
        train["train_name"], "|",
        train["from"], "->", train["to"], "|",
        train["duration"])
# Out:
# --- TRAIN SCHEDULE ---
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# 12951 | Mumbai Rajdhani Express | Mumbai Central (BCT) -> Delhi Junction (DLI) | 15h 35m
# 12952 | New Delhi Rajdhani Express | Delhi Junction (DLI) -> Mumbai Central (BCT) | 15h 20m
# 12163 | Chennai Superfast Express | Mumbai CST (CSTM) -> Chennai Central (MAS) | 27h 45m
# 12301 | Howrah Rajdhani Express | Howrah (HWH) -> Delhi Junction (DLI) | 19h 50m
# 12657 | Bangalore Mail | Chennai Central (MAS) -> Bangalore City (SBC) | 7h 30m
# 11301 | Udyan Express | Mumbai CST (CSTM) -> Bangalore City (SBC) | 27h 30m
# 12246 | Yuva Express | Howrah (HWH) -> Pune Junction (PUNE) | 33h 25m
# 19019 | Dehradun Express | Ahmedabad Junction (ADI) -> Delhi Junction (DLI) | 22h 50m
# 22691 | Rajdhani Express | Bangalore City (SBC) -> Delhi Junction (DLI) | 33h 30m
# 12621 | Tamil Nadu Express | Delhi Junction (DLI) -> Chennai Central (MAS) | 32h 40m

# %%
import requests
from bs4 import BeautifulSoup


class RailwayScraper:

    def __init__(self):
        self.base_url = "https://contentitvedant.github.io/Railway_Booking/"

    def get_soup(self, page):
        url = self.base_url + page
        response = requests.get(url)
        soup = BeautifulSoup(response.text, "html.parser")
        print("Fetched :", url, "| Status :", response.status_code)
        return soup

    def get_train_schedule(self):
        soup = self.get_soup("trains.html")
        table = soup.find(id="train-schedule-table")
        rows = table.find("tbody").find_all("tr")
        trains = []
        for row in rows:
            cells = row.find_all("td")
            trains.append({
                "train_no": cells[0].get_text(),
                "train_name": cells[1].get_text(),
                "from": cells[2].get_text(),
                "to": cells[3].get_text(),
                "departure": cells[4].get_text(),
                "arrival": cells[5].get_text(),
                "duration": cells[6].get_text(),
            })
        return trains

    def get_passengers(self):
        soup = self.get_soup("passengers.html")
        table = soup.find(id="passenger-records-table")
        rows = table.find("tbody").find_all("tr")
        passengers = []
        for row in rows:
            passengers.append({
                "pnr": row["data-pnr"],
                "name": row.find(class_="passenger-name").get_text(),
                "date": row.find(class_="journey-date").get_text(),
                "class": row.find(class_="travel-class").get_text(),
                "seat": row.find(class_="seat-number").get_text(),
                "fare": row.find(class_="fare").get_text(),
            })
        return passengers

    def get_seat_availability(self):
        soup = self.get_soup("seat-availability.html")
        table = soup.find(id="seat-availability-table")
        rows = table.find("tbody").find_all("tr")
        available = []
        for row in rows:
            available.append({
                "train_no": row["data-train"],
                "train_name": row.find(class_="train-name").get_text(),
                "seats_sl": row.find(class_="seats-sl").get_text(),
                "seats_3a": row.find(class_="seats-3a").get_text(),
                "seats_2a": row.find(class_="seats-2a").get_text(),
                "seats_1a": row.find(class_="seats-1a").get_text(),
            })
        return available


if __name__ == "__main__":
    scraper = RailwayScraper()

    print("\n--- TRAIN SCHEDULE ---")
    for train in scraper.get_train_schedule():
        print(
            train["train_no"], "|",
            train["train_name"], "|",
            train["from"], "->", train["to"], "|",
            train["duration"]
        )

    print("\n--- PASSENGER RECORDS ---")
    for passenger in scraper.get_passengers():
        print(
            "PNR:", passenger["pnr"], "|",
            "Name:", passenger["name"], "|",
            "Class:", passenger["class"], "|",
            "Seat:", passenger["seat"]
        )

    print("\n--- SEAT AVAILABILITY ---")
    for seat in scraper.get_seat_availability():
        print(
            "Train", seat["train_no"], "-",
            seat["train_name"], "|",
            "SL:", seat["seats_sl"], "|",
            "3A:", seat["seats_3a"], "|",
            "2A:", seat["seats_2a"]
        )
# Out:
# --- TRAIN SCHEDULE ---
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# 12951 | Mumbai Rajdhani Express | Mumbai Central (BCT) -> Delhi Junction (DLI) | 15h 35m
# 12952 | New Delhi Rajdhani Express | Delhi Junction (DLI) -> Mumbai Central (BCT) | 15h 20m
# 12163 | Chennai Superfast Express | Mumbai CST (CSTM) -> Chennai Central (MAS) | 27h 45m
# 12301 | Howrah Rajdhani Express | Howrah (HWH) -> Delhi Junction (DLI) | 19h 50m
# 12657 | Bangalore Mail | Chennai Central (MAS) -> Bangalore City (SBC) | 7h 30m
# 11301 | Udyan Express | Mumbai CST (CSTM) -> Bangalore City (SBC) | 27h 30m
# 12246 | Yuva Express | Howrah (HWH) -> Pune Junction (PUNE) | 33h 25m
# 19019 | Dehradun Express | Ahmedabad Junction (ADI) -> Delhi Junction (DLI) | 22h 50m
# 22691 | Rajdhani Express | Bangalore City (SBC) -> Delhi Junction (DLI) | 33h 30m
# 12621 | Tamil Nadu Express | Delhi Junction (DLI) -> Chennai Central (MAS) | 32h 40m
#
# --- PASSENGER RECORDS ---
# Fetched : https://contentitvedant.github.io/Railway_Booking/passengers.html | Status : 200
# PNR: 43821756 | Name: Rahul Sharma | Class: 3A | Seat: B4
# PNR: 67934521 | Name: Priya Menon | Class: 2A | Seat: A12
# PNR: 81204763 | Name: Arjun Nair | Class: SL | Seat: —
# PNR: 52983104 | Name: Sunita Rao | Class: 2A | Seat: C7
# PNR: 39047682 | Name: Vikram Patel | Class: 3A | Seat: D23
# PNR: 74512839 | Name: Kavya Iyer | Class: SL | Seat: —
# PNR: 60183475 | Name: Aditya Joshi | Class: 1A | Seat: A3
# PNR: 95261847 | Name: Deepa Krishnan | Class: 3A | Seat: B18
# PNR: 12873649 | Name: Mohan Das | Class: 2A | Seat: A6
# PNR: 48730261 | Name: Ananya Singh | Class: SL | Seat: C31
# PNR: 33918274 | Name: Ravi Kumar | Class: 3A | Seat: D9
# PNR: 76459013 | Name: Neha Gupta | Class: 3A | Seat: B55
#
# --- SEAT AVAILABILITY ---
# Fetched : https://contentitvedant.github.io/Railway_Booking/seat-availability.html | Status : 200
# Train 12951 - Mumbai Rajdhani Express | SL: — | 3A: 42 | 2A: 18
# Train 12952 - New Delhi Rajdhani Express | SL: — | 3A: 27 | 2A: 11
# Train 12163 - Chennai Superfast Express | SL: 14 | 3A: 5 | 2A: 2
# Train 12301 - Howrah Rajdhani Express | SL: — | 3A: 38 | 2A: 15
# Train 12657 - Bangalore Mail | SL: 0 | 3A: 0 | 2A: 0
# Train 11301 - Udyan Express | SL: 63 | 3A: 22 | 2A: 8
# Train 12246 - Yuva Express | SL: 3 | 3A: 1 | 2A: 0
# Train 19019 - Dehradun Express | SL: 81 | 3A: 34 | 2A: 12
# Train 22691 - Rajdhani Express | SL: — | 3A: 9 | 2A: 3
# Train 12621 - Tamil Nadu Express | SL: 0 | 3A: 0 | 2A: 0

# %%
file = open("train_schedule.txt", "w")

for t in train:
    for t in scraper.get_train_schedule():
        file.write(
            t["train_no"] + " - " + t["train_name"] + "\n"
        )

file.close()

print("Train schedule saved successfully.")
# Out:
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# Train schedule saved successfully.

# %%
file = open("train_schedule.txt", "r")

print("Stored Train Schedule")
print("=" * 40)

print(file.read())

file.close()
# Out:
# Stored Train Schedule
# ========================================
# 12951 - Mumbai Rajdhani Express
# 12952 - New Delhi Rajdhani Express
# 12163 - Chennai Superfast Express
# 12301 - Howrah Rajdhani Express
# 12657 - Bangalore Mail
# 11301 - Udyan Express
# 12246 - Yuva Express
# 19019 - Dehradun Express
# 22691 - Rajdhani Express
# 12621 - Tamil Nadu Express
# 12951 - Mumbai Rajdhani Express
# 12952 - New Delhi Rajdhani Express
# 12163 - Chennai Superfast Express
# 12301 - Howrah Rajdhani Express
# 12657 - Bangalore Mail
# 11301 - Udyan Express
# 12246 - Yuva Express
# 19019 - Dehradun Express
# 22691 - Rajdhani Express
# 12621 - Tamil Nadu Express
# 12951 - Mumbai Rajdhani Express
# 12952 - New Delhi Rajdhani Express
# 12163 - Chennai Superfast Express
# 12301 - Howrah Rajdhani Express
# 12657 - Bangalore Mail
# 11301 - Udyan Express
# 12246 - Yuva Express
# 19019 - Dehradun Express
# 22691 - Rajdhani Express
# 12621 - Tamil Nadu Express
# 12951 - Mumbai Rajdhani Express
# 12952 - New Delhi Rajdhani Express
# 12163 - Chennai Superfast Express
# 12301 - Howrah Rajdhani Express
# 12657 - Bangalore Mail
# 11301 - Udyan Express
# 12246 - Yuva Express
# 19019 - Dehradun Express
# 22691 - Rajdhani Express
# 12621 - Tamil Nadu Express
# 12951 - Mumbai Rajdhani Express
# 12952 - New Delhi Rajdhani Express
# 12163 - Chennai Superfast Express
# 12301 - Howrah Rajdhani Express
# 12657 - Bangalore Mail
# 11301 - Udyan Express
# 12246 - Yuva Express
# 19019 - Dehradun Express
# 22691 - Rajdhani Express
# 12621 - Tamil Nadu Express
# 12951 - Mumbai Rajdhani Express
# 12952 - New Delhi Rajdhani Express
# 12163 - Chennai Superfast Express
# 12301 - Howrah Rajdhani Express
# 12657 - Bangalore Mail
# 11301 - Udyan Express
# 12246 - Yuva Express
# 19019 - Dehradun Express
# 22691 - Rajdhani Express
# 12621 - Tamil Nadu Express
# 12951 - Mumbai Rajdhani Express
# 12952 - New Delhi Rajdhani Express
# 12163 - Chennai Superfast Express
# 12301 - Howrah Rajdhani Express
# 12657 - Bangalore Mail
# 11301 - Udyan Express
# 12246 - Yuva Express
# 19019 - Dehradun Express
# 22691 - Rajdhani Express
# 12621 - Tamil Nadu Express

# %%
import csv 
with open("train_schedule.csv", "w", newline="") as file:

    writer = csv.writer(file)

    writer.writerow([
        "Train Number",
        "Train Name",
        "From",
        "To",
        "Departure",
        "Arrival",
        "Duration"
    ])

    for t in scraper.get_train_schedule():

        writer.writerow([
            t["train_no"],
            t["train_name"],
            t["from"],
            t["to"],
            t["departure"],
            t["arrival"],
            t["duration"]
        ])
 
print("CSV file created successfully.")
# Out:
# Fetched : https://contentitvedant.github.io/Railway_Booking/trains.html | Status : 200
# CSV file created successfully.
