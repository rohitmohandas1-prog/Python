# %%
def greet(name):
    print("Hello,", name)
greet("Alice")
# Out:
# Hello, Alice

# %%
def ticket_details(**details):
   print("Ticket Information:")
   for key, value in details.items():
       print(key, ":", value)

ticket_details(
passenger_name="Rahul Sharma",
train_name="Rajdhani Express",
seat_number="B1-21",
fare=2500,
status="Confirmed")
# Out:
# Ticket Information:
# passenger_name : Rahul Sharma
# train_name : Rajdhani Express
# seat_number : B1-21
# fare : 2500
# status : Confirmed

# %%
def reservation_status(
   passenger_name,
   ticket_status="Confirmed"):
   print("Passenger Name :", passenger_name)
   print("Ticket Status :", ticket_status)

reservation_status("Rahul Sharma")
reservation_status("Amit Verma", "Waiting")
# Out:
# Passenger Name : Rahul Sharma
# Ticket Status : Confirmed
# Passenger Name : Amit Verma
# Ticket Status : Waiting

# %%
def seat_countdown(seats):
   while seats == 0:
       print("All seats are booked!")
       return
   print("Remaining seats:", seats)
   seat_countdown(seats - 1)

# %%
seat_countdown(5)
# Out:
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# All seats are booked!
# Remaining seats: 5
# Remaining seats: 4
# Remaining seats: 3
# Remaining seats: 2
# Remaining seats: 1
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
# ...
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 8, in seat_countdown(seats)
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#       7
# ----> 8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 6, in seat_countdown(seats)
#       2    while seats == 0:
#       3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
# ----> 6    seat_countdown(seats - 1)
#       7
#       8    seat_countdown(5)
#
# Cell In[3], line 3, in seat_countdown(seats)
#       1 def seat_countdown(seats):
#       2    while seats == 0:
# ----> 3        print("All seats are booked!")
#       4        return
#       5    print("Remaining seats:", seats)
#       6    seat_countdown(seats - 1)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\iostream.py:762, in OutStream.write(self, string)
#     759     msg = "I/O operation on closed file"
#     760     raise ValueError(msg)
# --> 762 is_child = not self._is_master_process()
#     763 # only touch the buffer in the IO thread to avoid races
#     764 with self._buffer_lock:
#
# RecursionError: maximum recursion depth exceeded
